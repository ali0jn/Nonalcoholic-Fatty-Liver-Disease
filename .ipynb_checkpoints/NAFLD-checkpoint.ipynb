# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impyute.imputation.cs import fast_knn
from sklearn.preprocessing import StandardScaler
from pandas.plotting import scatter_matrix
import seaborn as sn
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # DATA PREPARATION

# %%
df = pd.read_excel('NAFLD.xlsx')
df_X = df.iloc[:, 1:-11]
df_X.rename(columns={'Smoking Status (Never Smoked=1, Left Smoking=2, Smoking=3)': 'Smoking Status'}, inplace=True)
sig_fib_y = pd.DataFrame(df.iloc[:, -5])
adv_fib_y = pd.DataFrame(df.iloc[:, -4])
sig_fib_y.rename(columns={'Significant Fibrosis (No=0, Yes=1) (If Fibrosis 2 and above, there is Significant Fibrosis)': 'Significant Fibrosis'}, inplace=True)
adv_fib_y.rename(columns={'Advanced Fibrosis (No=0, Yes=1) (If Fibrosis is 3 and above, there is Advanced Fibrosis)': 'Advanced Fibrosis'}, inplace=True)

# %%
nan_columns = df_X.columns[df_X.isna().any()].tolist()
X_columns_1 = df_X.isna().sum().sort_values(ascending=False)[-15:].index   # features with no missing values
X_columns_2 = df_X.isna().sum().sort_values(ascending=False)[15:].index    # features <= 25% missing values threshold
X_baseline_1 = df_X[X_columns_1]   # Data Frame of features with no missing values
X_baseline_2 = df_X[X_columns_2]   # Data Frame of features with <= 25% missing values threshold

# %%
X_baseline_1.head()   # 605 x 15
# Out:
#    Diastolic Blood Pressure  Gender (Female=1, Male=2)  Height  Weight  \
# 0                        77                          1     150      80
# 1                        72                          1     154      73
# 2                        80                          2     170     101
# 3                        83                          2     175      95
# 4                        79                          2     162      68
#
#    Body Mass Index  Systolic Blood Pressure  Diyabetes Mellitus (No=0, Yes=1)  \
# 0            35.56                      135                                 0
# 1            30.78                      120                                 0
# 2            34.95                      120                                 1
# 3            31.02                      124                                 1
# 4            25.91                      124                                 0
#
# ...

# %%
X_baseline_2.head()   # 605 x 35
# Out:
#    Total Protein    LDH  Hemoglobin - A1C  Waist Circumference  \
# 0            7.7  281.0               NaN                119.0
# 1            7.2  219.0               NaN                101.0
# 2            8.4  263.0              4.70                116.0
# 3            7.6  166.0              4.70                114.0
# 4            7.9  376.0              4.82                101.0
#
#    Smoking Status  Ferritin  Mean Platelet Volume  Hip Circumference  Glucose  \
# 0             2.0     524.0                   9.2              104.0    119.0
# 1             1.0      41.3                   8.1               98.0      NaN
# 2             2.0     294.0                   9.3              112.0     93.0
# 3             2.0      46.0                   7.1              114.0     90.0
# 4             2.0     158.0                   7.4               97.0     89.0
#
#      LDL  ...  Systolic Blood Pressure  Diyabetes Mellitus (No=0, Yes=1)  \
# ...

# %%
sig_fib_y.head()   # 605 x 1
# Out:
#    Significant Fibrosis
# 0                     0
# 1                     0
# 2                     1
# 3                     0
# 4                     0

# %%
adv_fib_y.head()   # 605 x 1
# Out:
#    Advanced Fibrosis
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0

# %% [markdown]
# ## Imputation using fast_knn(k=30)

# %%
nan_columns = df_X.columns[df_X.isna().any()]   # features list with NaN values
X_baseline_2 = fast_knn(X_baseline_2, k=30)
X_baseline_2.columns=X_columns_2
nan_columns
# Out:
# Index(['Waist Circumference', 'Hip Circumference', 'Smoking Status', 'ALP',
#        'GGT', 'LDH', 'Total Bilirubin', 'Direct Bilirubin', 'Total Protein',
#        'Triglycerides', 'HDL', 'LDL', 'Microalbumin Spot Urine',
#        'Microalbumin/Creatinine Ratio', 'TSH', 'CK', 'Leukocyte', 'Hemoglobin',
#        'Trombosit', 'Mean Corpuscular Volume', 'Mean Platelet Volume', 'PT',
#        'INR', 'Vitamin D', 'Ferritin', 'Ceruloplasmin', 'C Peptide', 'Glucose',
#        'Insulin', 'HOMA',
#        'Insulin resistance according to HOMA (insulin resistance = 1, no insulin resistance = 2)',
#        'Uric Acid', 'BUN', 'Creatinine', 'Hemoglobin - A1C'],
#       dtype='object')

# %%
X_baseline_2.head()   # Data Frame of features <= 25% missing value threshold after imputation
# Out:
#    Total Protein    LDH  Hemoglobin - A1C  Waist Circumference  \
# 0            7.7  281.0          5.877303                119.0
# 1            7.2  219.0          6.107008                101.0
# 2            8.4  263.0          4.700000                116.0
# 3            7.6  166.0          4.700000                114.0
# 4            7.9  376.0          4.820000                101.0
#
#    Smoking Status  Ferritin  Mean Platelet Volume  Hip Circumference  \
# 0             2.0     524.0                   9.2              104.0
# 1             1.0      41.3                   8.1               98.0
# 2             2.0     294.0                   9.3              112.0
# 3             2.0      46.0                   7.1              114.0
# 4             2.0     158.0                   7.4               97.0
#
#       Glucose    LDL  ...  Systolic Blood Pressure  \
# 0  119.000000   95.0  ...                    135.0
# 1  115.021475   97.0  ...                    120.0
# ...

# %% [markdown]
# ## Normalizing features using StandardScaler

# %%
sc = StandardScaler()
std_baseline_1 = sc.fit_transform(X_baseline_1)
std_baseline_2 = sc.fit_transform(X_baseline_2)
X_baseline_1 = pd.DataFrame(std_baseline_1, dtype=float, columns=X_columns_1)
X_baseline_2 = pd.DataFrame(std_baseline_2, dtype=float, columns=X_columns_2)

# %%
X_baseline_1.head()   # Normalized Data Frame of features with no missing values
# Out:
#    Diastolic Blood Pressure  Gender (Female=1, Male=2)    Height    Weight  \
# 0                 -0.545937                  -1.063147 -1.492133 -0.445686
# 1                 -1.049277                  -1.063147 -1.088584 -0.932904
# 2                 -0.243933                   0.940604  0.525615  1.015967
# 3                  0.058071                   0.940604  1.030052  0.598352
# 4                 -0.344601                   0.940604 -0.281484 -1.280917
#
#    Body Mass Index  Systolic Blood Pressure  Diyabetes Mellitus (No=0, Yes=1)  \
# 0         0.723409                 0.504769                         -0.769484
# 1        -0.213363                -0.475497                         -0.769484
# 2         0.603863                -0.475497                          1.299573
# 3        -0.166328                -0.214092                          1.299573
# 4        -1.167772                -0.214092                         -0.769484
#
# ...

# %%
X_baseline_2.head()   # Normalized Data Frame of features <= 25% missing value threshold
# Out:
#    Total Protein       LDH  Hemoglobin - A1C  Waist Circumference  \
# 0      -0.181906  0.362000         -0.139524             0.923875
# 1      -1.349523 -0.320122          0.096143            -0.818197
# 2       1.452758  0.163964         -1.347387             0.633530
# 3      -0.415429 -0.903227         -1.347387             0.439966
# 4       0.285141  1.407187         -1.224272            -0.818197
#
#    Smoking Status  Ferritin  Mean Platelet Volume  Hip Circumference  \
# 0        0.384817  3.302281              0.321794          -0.030008
# 1       -0.975642 -0.729175             -0.540634          -0.611481
# 2        0.384817  1.381347              0.400196           0.745289
# 3        0.384817 -0.689922             -1.324659           0.939114
# 4        0.384817  0.245490             -1.089451          -0.708393
#
#     Glucose       LDL  ...  Systolic Blood Pressure  \
# 0  0.331022 -0.913031  ...                 0.504769
# ...

# %% [markdown]
# # DATA EXPLORATION

# %%
plt.figure(figsize=(11, 11))
sn.heatmap(X_baseline_1.corr(), annot=True, linewidths=0.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
plt.figure(figsize=(20, 20))
sn.heatmap(X_baseline_2.corr(), annot=True, linewidths=0.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
X_baseline_1.hist(figsize=(15, 15), bins=50).shape   # visualizing the distribution of features in dataset (no missing values)
# Out:
# (4, 4)

# %%
X_baseline_2.hist(figsize=(20, 20), bins=50).shape  # visualizing the distribution of features in dataset (25% missing values threshold)
# Out:
# (6, 6)

# %%
temp = X_baseline_1.join(adv_fib_y)
correlation = temp.corr()[adv_fib_y.columns].abs()
baseline_1_adv = correlation.sort_values(by=[adv_fib_y.columns[0]], ascending=False)[1:6]   # top 5 pos_corr (features with no missing values and adv_fib)
baseline_1_adv
# Out:
#                                   Advanced Fibrosis
# Diyabetes Mellitus (No=0, Yes=1)           0.302165
# Age                                        0.229799
# Body Mass Index                            0.166048
# Hypertension (No=0, Yes=1)                 0.160676
# Height                                     0.125120

# %%
temp = X_baseline_1.join(sig_fib_y)
correlation = temp.corr()[sig_fib_y.columns].abs()
baseline_1_sig = correlation.sort_values(by=[sig_fib_y.columns[0]], ascending=False)[1:6]   # top 5 abs_corr (features with no missing values and sig_fib)
baseline_1_sig
# Out:
#                                   Significant Fibrosis
# Diyabetes Mellitus (No=0, Yes=1)              0.295710
# Age                                           0.236602
# Body Mass Index                               0.151655
# Hypertension (No=0, Yes=1)                    0.147724
# AST                                           0.109171

# %%
temp = X_baseline_2.join(adv_fib_y)
correlation = temp.corr()[adv_fib_y.columns].abs()
baseline_2_adv = correlation.sort_values(by=[adv_fib_y.columns[0]], ascending=False)[1:6]   # top 5 abs_corr (features <= 25% missing value threshold and adv_fib)
baseline_2_adv
# Out:
#                                   Advanced Fibrosis
# Diyabetes Mellitus (No=0, Yes=1)           0.302165
# Hemoglobin - A1C                           0.260040
# Age                                        0.229799
# Trombosit                                  0.220239
# Glucose                                    0.206417

# %%
temp = X_baseline_2.join(sig_fib_y)
correlation = temp.corr()[sig_fib_y.columns].abs()
baseline_2_sig = correlation.sort_values(by=[sig_fib_y.columns[0]], ascending=False)[1:6]   # top 5 abs_corr (features <= 25% missing values and sig_fib)
baseline_2_sig
# Out:
#                                   Significant Fibrosis
# Diyabetes Mellitus (No=0, Yes=1)              0.295710
# Age                                           0.236602
# Hemoglobin - A1C                              0.235719
# Glucose                                       0.199778
# Trombosit                                     0.175854

# %%
baseline_1_adv_corr = X_baseline_1[baseline_1_adv.index]   # scatter plot abs_corr (features with no missing value and adv_fib) against each other
scatter_matrix(baseline_1_adv_corr, alpha=1.0, diagonal='kde', figsize=(12, 12)).shape
# Out:
# (5, 5)

# %%
baseline_1_sig_corr = X_baseline_1[baseline_1_sig.index]   # scatter plot abs_corr (features with no missing value and sig_fib) against each other
scatter_matrix(baseline_1_sig_corr, alpha=1.0, diagonal='kde', figsize=(12, 12)).shape
# Out:
# (5, 5)

# %%
baseline_2_adv_corr = X_baseline_2[baseline_2_adv.index]   # scatter plot abs_corr (features <= 25% missing value and adv_fib) against each other
scatter_matrix(baseline_2_adv_corr, alpha=1.0, diagonal='kde', figsize=(12, 12)).shape
# Out:
# (5, 5)

# %%
baseline_2_sig_corr = X_baseline_2[baseline_2_sig.index]   # scatter plot abs_corr (features <= 25% missing value and sig_fib) against each other
scatter_matrix(baseline_2_sig_corr, alpha=1.0, diagonal='kde', figsize=(12, 12)).shape
# Out:
# (5, 5)

# %% [markdown]
# # Learning Models

# %%
def plot_confusion_matrix(clf, X_train, y_train, X_test, y_test, title):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    sn.heatmap(cm, annot=True, linewidths=0.5, cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.show()

# %%
def get_metrics(clf, X_train, y_train, X_test, y_test, label):
    clf.fit(X_train, y_train)
    y_prob = clf.predict_proba(X_test)
    y_pred = clf.predict(X_test)
    auc_score = roc_auc_score(y_test, y_prob[:, 1])
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    sensitivity = tp / (tp + fn)    # also called recall and true positive rate
    specificity = tn / (tn + fp)    # also called true negative rate
    ppv = round(tp / (tp + fp), 3)    # also called precision
    npv = round(tn / (tn + fn), 3)
    plr = round(sensitivity / (1 - specificity), 3)
    nlr = round((1 - sensitivity) / specificity, 3)
    return ['NA', label, round(sensitivity * 100, 0), round(specificity * 100, 0), fn, fp, ppv, npv, plr, nlr, round(auc_score, 3)]

# %%
def get_roc_auc_score(clf, X_train, y_train, X_test, y_test, label):
    clf.fit(X_train, y_train)
    probs = clf.predict_proba(X_test)
    auc = roc_auc_score(y_test, probs[:, 1])
    fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
    return auc, fpr, tpr, thresholds, label

# %%
def plot_roc_curve(X_train, y_train, X_test, y_test, title):
    scores = [get_roc_auc_score(clf, X_train, y_train, X_test, y_test, label) for clf, label in 
              [(LogisticRegression(), 'LR'), (SVC(probability=True), 'SVM'), (RandomForestClassifier(), 'RF'), (BaggingClassifier(), 'Bag.')]]
    plt.plot(scores[0][1], scores[0][2], marker='.', color='black', label='{}: {}'.format(scores[0][4], round(scores[0][0], 2)))
    plt.plot(scores[1][1], scores[1][2], marker='.', color='red', label='{}: {}'.format(scores[1][4], round(scores[1][0], 2)))
    plt.plot(scores[2][1], scores[2][2], marker='.', color='blue', label='{}: {}'.format(scores[2][4], round(scores[2][0], 2)))
    plt.plot(scores[3][1], scores[3][2], marker='.', color='green', label='{}: {}'.format(scores[3][4], round(scores[3][0], 2)))
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive')
    plt.ylabel('True Positive')
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# ### Classification Models performance on Advanced Fibrosis with 0 and 25% missing values

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
X_train_0, X_test_0, y_train_0, y_test_0 = train_test_split(X_baseline_1, adv_fib_y, random_state=0, test_size=0.2, stratify=adv_fib_y)
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_baseline_2, adv_fib_y, random_state=0, test_size=0.2, stratify=adv_fib_y)

# %%
plot_confusion_matrix(LogisticRegression(), X_train_0, y_train_0, X_test_0, y_test_0, 'Logistic Regression Confusion Matrix (no missing value)')
plot_confusion_matrix(LogisticRegression(), X_train_1, y_train_1, X_test_1, y_test_1, 'Logistic Regression Confusion Matrix (25% missing value)')

# %%
plot_confusion_matrix(SVC(), X_train_0, y_train_0, X_test_0, y_test_0, 'SVM Confusion Matrix (no missing value)')
plot_confusion_matrix(SVC(), X_train_1, y_train_1, X_test_1, y_test_1, 'SVM Confusion Matrix (25% missing value)')

# %%
plot_confusion_matrix(RandomForestClassifier(n_estimators=1000), X_train_0, y_train_0, X_test_0, y_test_0, 'Random Forest Confusion Matrix (no missing value)')
plot_confusion_matrix(RandomForestClassifier(n_estimators=1000), X_train_1, y_train_1, X_test_1, y_test_1, 'Random Forest Confusion Matrix (25% missing value)')

# %%
plot_confusion_matrix(BaggingClassifier(), X_train_0, y_train_0, X_test_0, y_test_0, 'Bagging Confusion Matrix (no missing value)')
plot_confusion_matrix(BaggingClassifier(), X_train_1, y_train_1, X_test_1, y_test_1, 'Bagging Confusion Matrix (25% missing value)')

# %%
plot_roc_curve(X_train_0, y_train_0, X_test_0, y_test_0, 'ROC Curve - Advanced Fibrosis (no missing value)')
plot_roc_curve(X_train_1, y_train_1, X_test_1, y_test_1, 'ROC Curve - Advanced Fibrosis (25% missing value)')

# %%
log_reg_metrics_0 = get_metrics(LogisticRegression(), X_train_0, y_train_0, X_test_0, y_test_0, 'LR 0 missing')
svm_metrics_0 = get_metrics(SVC(probability=True), X_train_0, y_train_0, X_test_0, y_test_0, 'SVM 0 missing')
rf_metrics_0 = get_metrics(RandomForestClassifier(), X_train_0, y_train_0, X_test_0, y_test_0, 'RF 0 missing')
bagging_metrics_0 = get_metrics(BaggingClassifier(), X_train_0, y_train_0, X_test_0, y_test_0, 'Bagging 0 missing')
log_reg_metrics_1 = get_metrics(LogisticRegression(), X_train_1, y_train_1, X_test_1, y_test_1, 'LR 25% missing')
svm_metrics_1 = get_metrics(SVC(probability=True), X_train_1, y_train_1, X_test_1, y_test_1, 'SVM 25% missing')
rf_metrics_1 = get_metrics(RandomForestClassifier(), X_train_1, y_train_1, X_test_1, y_test_1, 'RF 25% missing')
bagging_metrics_1 = get_metrics(BaggingClassifier(), X_train_1, y_train_1, X_test_1, y_test_1, 'Bagging 25% missing')

# %%
methods_metrics = np.array([['FIB-4 <1.3', 'NA', '64', '74', '0.358', '0.262', '0.342', '0.907', '2.452', '0.485', '0.731'], 
                         ['FIB-4 >2.67', 'NA', '15', '97', '0.852', '0.029', '0.522', '0.843', '5.145', '0.877', '0.731'],
                         ['NFS <-1.455', 'NA', '71', '63', '0.284', '0.369', '0.291', '0.913', '1.940', '0.450', '0.715'],
                         ['NFS >0.676', 'NA', '15', '96', '0.852', '0.037', '0.462', '0.842', '4.042', '0.884', '0.715'],
                         log_reg_metrics_0, svm_metrics_0, rf_metrics_0, bagging_metrics_0,
                         log_reg_metrics_1, svm_metrics_1, rf_metrics_1, bagging_metrics_1])

table_df = pd.DataFrame(methods_metrics, columns=['Cutoff', 'Classifier', 'Sensitivity %', 'Specificity %', 'FN',
                                                  'FP', 'PPV', 'NPV', 'PLR', 'NLR', 'AUC'])
# print(table_df.to_string(justify='center', index=False, col_space=7))
table_df
# Out:
#          Cutoff           Classifier Sensitivity % Specificity %     FN  \
# 0    FIB-4 <1.3                   NA            64            74  0.358
# 1   FIB-4 >2.67                   NA            15            97  0.852
# 2   NFS <-1.455                   NA            71            63  0.284
# 3    NFS >0.676                   NA            15            96  0.852
# 4            NA         LR 0 missing          18.0          95.0     18
# 5            NA        SVM 0 missing           9.0          98.0     20
# 6            NA         RF 0 missing          23.0          96.0     17
# 7            NA    Bagging 0 missing          27.0          89.0     16
# 8            NA       LR 25% missing          36.0          91.0     14
# 9            NA      SVM 25% missing          14.0         100.0     19
# 10           NA       RF 25% missing          18.0          98.0     18
# 11           NA  Bagging 25% missing          27.0          98.0     16
#
# ...

# %%
def get_feature_importance(X_train, y_train, df, fig_size):
    plt.figure(figsize=fig_size)
    features = df.columns
    rf = RandomForestClassifier()
    rf.fit(X_train, y_train)
    importances = rf.feature_importances_
    indices = np.argsort(importances)[::-1]
    values = [round(i,5) for i in importances[indices]]
    plt.barh(features[indices][::-1], values[::-1])
    plt.title('Feature Importance Scores by RF')
    plt.show()
    print(values)

# %%
get_feature_importance(X_train_0, y_train_0, X_baseline_1, (20, 10))
# Out:
# [0.13337, 0.11293, 0.10823, 0.08571, 0.08293, 0.08059, 0.07467, 0.07462, 0.06986, 0.06815, 0.053, 0.01862, 0.01559, 0.01294, 0.0088]

# %%
get_feature_importance(X_train_1, y_train_1, X_baseline_2, (20, 15))
# Out:
# [0.07689, 0.05675, 0.05249, 0.04986, 0.04513, 0.04479, 0.04202, 0.03958, 0.03824, 0.03739, 0.03196, 0.03152, 0.03098, 0.03081, 0.03058, 0.03005, 0.02877, 0.02723, 0.02673, 0.02671, 0.0257, 0.02491, 0.02357, 0.02332, 0.0204, 0.01965, 0.01902, 0.01845, 0.01083, 0.00997, 0.00808, 0.00635, 0.00388, 0.0038, 0.0036]
